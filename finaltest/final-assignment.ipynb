# %%
import pandas as pd

# %%
df=pd.read_csv('data/2315676.csv', na_values=-9999, sep='\s+', skiprows=[1])

# %%
df.head()
# Out:
#              STATION      STATION_NAME      DATE  TAVG  TMAX  TMIN
# 0  GHCND:FI000007501  SODANKYLA-AWS-FI  19080101   NaN   2.0 -37.0
# 1  GHCND:FI000007501  SODANKYLA-AWS-FI  19080102   NaN   6.0 -26.0
# 2  GHCND:FI000007501  SODANKYLA-AWS-FI  19080103   NaN   7.0 -27.0
# 3  GHCND:FI000007501  SODANKYLA-AWS-FI  19080104   NaN  -3.0 -27.0
# 4  GHCND:FI000007501  SODANKYLA-AWS-FI  19080105   NaN   4.0 -36.0

# %%
df_1984=df.loc[((df['DATE']>=19840101) & (df['DATE']<=19841231))]

# %%
df_1984
# Out:
#                  STATION      STATION_NAME      DATE  TAVG  TMAX  TMIN
# 27675  GHCND:FI000007501  SODANKYLA-AWS-FI  19840101   6.0   9.0  -2.0
# 27676  GHCND:FI000007501  SODANKYLA-AWS-FI  19840102   7.0   8.0   3.0
# 27677  GHCND:FI000007501  SODANKYLA-AWS-FI  19840103  10.0  17.0   8.0
# 27678  GHCND:FI000007501  SODANKYLA-AWS-FI  19840104   4.0  10.0  -2.0
# 27679  GHCND:FI000007501  SODANKYLA-AWS-FI  19840105   9.0  13.0 -10.0
# ...                  ...               ...       ...   ...   ...   ...
# 28036  GHCND:FI000007501  SODANKYLA-AWS-FI  19841227  22.0  23.0  22.0
# 28037  GHCND:FI000007501  SODANKYLA-AWS-FI  19841228  24.0  26.0  20.0
# 28038  GHCND:FI000007501  SODANKYLA-AWS-FI  19841229  19.0  21.0  21.0
# 28039  GHCND:FI000007501  SODANKYLA-AWS-FI  19841230   2.0   4.0   0.0
# 28040  GHCND:FI000007501  SODANKYLA-AWS-FI  19841231  10.0  21.0  -9.0
#
# [366 rows x 6 columns]

# %%
df_1984['TAVG_NEW']=df_1984['TAVG'].fillna((df['TMAX']+df['TMIN'])/2)
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\3544516183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1984['TAVG_NEW']=df_1984['TAVG'].fillna((df['TMAX']+df['TMIN'])/2)

# %%
df_1984['TAVG_NEW']=(df_1984['TAVG_NEW']-32)/1.8
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\1799992199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1984['TAVG_NEW']=(df_1984['TAVG_NEW']-32)/1.8

# %%
temps_winter=df_1984.loc[(((df_1984['DATE']>=19840101) & (df_1984['DATE']<=19840229)) | ((df_1984['DATE']>=19841201) & (df_1984['DATE']<=19841231)))]
temps_winter['DATE']=pd.to_datetime(temps_winter['DATE'], format='%Y%m%d')
temps_winter
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\979706943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_winter['DATE']=pd.to_datetime(temps_winter['DATE'], format='%Y%m%d')
#                  STATION      STATION_NAME       DATE  TAVG  TMAX  TMIN  \
# 27675  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-01-01   6.0   9.0  -2.0
# 27676  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-01-02   7.0   8.0   3.0
# 27677  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-01-03  10.0  17.0   8.0
# 27678  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-01-04   4.0  10.0  -2.0
# 27679  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-01-05   9.0  13.0 -10.0
# ...                  ...               ...        ...   ...   ...   ...
# ...

# %%
temps_spring=df_1984.loc[((df_1984['DATE']>=19840301) & (df_1984['DATE']<=19840531))]
temps_spring['DATE']=pd.to_datetime(temps_spring['DATE'], format='%Y%m%d')
temps_spring
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\2310479622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_spring['DATE']=pd.to_datetime(temps_spring['DATE'], format='%Y%m%d')
#                  STATION      STATION_NAME       DATE  TAVG  TMAX  TMIN  \
# 27735  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-03-01  26.0  29.0  27.0
# 27736  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-03-02  11.0  13.0   7.0
# 27737  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-03-03   8.0  15.0  -4.0
# 27738  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-03-04   2.0  18.0 -21.0
# 27739  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-03-05  24.0  27.0  18.0
# ...                  ...               ...        ...   ...   ...   ...
# ...

# %%
temps_summer=df_1984.loc[((df_1984['DATE']>=19840601) & (df_1984['DATE']<=19840831))]
temps_summer['DATE']=pd.to_datetime(temps_summer['DATE'], format='%Y%m%d')
temps_summer
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\1893494941.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_summer['DATE']=pd.to_datetime(temps_summer['DATE'], format='%Y%m%d')
#                  STATION      STATION_NAME       DATE  TAVG  TMAX  TMIN  \
# 27827  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-06-01  66.0  76.0  47.0
# 27828  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-06-02  62.0  74.0  51.0
# 27829  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-06-03  63.0  77.0  42.0
# 27830  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-06-04  59.0  72.0  46.0
# 27831  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-06-05  50.0  60.0  41.0
# ...                  ...               ...        ...   ...   ...   ...
# ...

# %%
temps_autumn=df_1984.loc[((df_1984['DATE']>=19840901) & (df_1984['DATE']<=19841130))]
temps_autumn['DATE']=pd.to_datetime(temps_autumn['DATE'], format='%Y%m%d')
temps_autumn
# Out:
# C:\Users\koroh\AppData\Local\Temp\ipykernel_35228\1510949191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_autumn['DATE']=pd.to_datetime(temps_autumn['DATE'], format='%Y%m%d')
#                  STATION      STATION_NAME       DATE  TAVG  TMAX  TMIN  \
# 27919  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-09-01  38.0  49.0  33.0
# 27920  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-09-02  40.0  49.0  30.0
# 27921  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-09-03  39.0  48.0  32.0
# 27922  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-09-04  36.0  48.0  23.0
# 27923  GHCND:FI000007501  SODANKYLA-AWS-FI 1984-09-05  39.0  51.0  24.0
# ...                  ...               ...        ...   ...   ...   ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (8,8))
plt.plot(temps_winter['DATE'],temps_winter['TAVG_NEW'])
plt.title('Winter')
# Out:
# Text(0.5, 1.0, 'Winter')

# %%
fig, ax = plt.subplots(figsize = (8,8))
plt.plot(temps_spring['DATE'],temps_spring['TAVG_NEW'], color='orange')
plt.title('Spring')
# Out:
# Text(0.5, 1.0, 'Spring')

# %%
fig, ax = plt.subplots(figsize = (8,8))
plt.plot(temps_summer['DATE'],temps_summer['TAVG_NEW'], color='green')
plt.title('Summer')
# Out:
# Text(0.5, 1.0, 'Summer')

# %%
fig, ax = plt.subplots(figsize = (8,8))
plt.plot(temps_autumn['DATE'],temps_autumn['TAVG_NEW'], color='red')
plt.title('Autumn')
# Out:
# Text(0.5, 1.0, 'Autumn')
